# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("API_KEY")

# %%
lista_años = ["1990", "1995", "2000", "2005", "2010", "2015", "2020"]

# %%
df_drama = pd.DataFrame()
for año in lista_años:
	url = "https://moviesdatabase.p.rapidapi.com/titles"

	querystring = {"genre":"Drama","startYear":str(año) ,"sort":"year.incr"}
	headers = {
		"x-rapidapi-key": API_KEY,
		"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	data = response.json()
	df_temp = pd.DataFrame(data['results'])
	df_drama = pd.concat([df_temp, df_drama], ignore_index=True)
	print(response.json())
# Out:
# {'page': 1, 'next': '/titles?genre=Drama&startYear=1990&sort=year.incr&page=2', 'entries': 10, 'results': [{'_id': '61e580c3971a4a15d641458b', 'id': 'tt0059325', 'primaryImage': {'id': 'rm3431504896', 'width': 292, 'height': 475, 'url': 'https://m.media-amazon.com/images/M/MV5BMTc0Mzk0Mjg2MF5BMl5BanBnXkFtZTcwMzU4NzAyMQ@@._V1_.jpg', 'caption': {'plainText': 'Jahrgang 45 (1990)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Jahrgang 45', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Jahrgang 45', '__typename': 'TitleText'}, 'releaseYear': {'year': 1990, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 11, 'month': 10, 'year': 1990, '__typename': 'ReleaseDate'}}, {'_id': '61e580c8d8f3c0931e414665', 'id': 'tt0059900', 'primaryImage': {'id': 'rm2847710208', 'width': 290, 'height': 475, 'url': 'https://m.media-amazon.c
# ...

# %%
df_drama["genero"] = "drama"

# %%
df_comedy = pd.DataFrame()
for año in lista_años:
	url = "https://moviesdatabase.p.rapidapi.com/titles"

	querystring = {"genre":"Comedy","startYear":str(año) ,"sort":"year.incr"}
	headers = {
		"x-rapidapi-key": API_KEY,
		"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	data = response.json()
	df_temp = pd.DataFrame(data['results'])
	df_comedy = pd.concat([df_temp, df_comedy], ignore_index=True)
	print(response.json())
# Out:
# {'page': 1, 'next': '/titles?genre=Comedy&startYear=1990&sort=year.incr&page=2', 'entries': 10, 'results': [{'_id': '61e58135d8f3c0931e41599d', 'id': 'tt0090665', 'primaryImage': {'id': 'rm3771178240', 'width': 341, 'height': 475, 'url': 'https://m.media-amazon.com/images/M/MV5BNzk3NjEyODcyNV5BMl5BanBnXkFtZTcwMjIyMDUyMQ@@._V1_.jpg', 'caption': {'plainText': 'Asfour Stah (1990)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Asfour Stah', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Asfour Stah', '__typename': 'TitleText'}, 'releaseYear': {'year': 1990, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 8, 'month': 3, 'year': 1991, '__typename': 'ReleaseDate'}}, {'_id': '61e58138909c2ca781415a01', 'id': 'tt0093082', 'primaryImage': None, 'titleType': {'text': 'TV Movie', 'id': 'tvMovie', 'isSeries': False, 'isEpisod
# ...

# %%
df_comedy["genero"] = "comedy"

# %%
df_Action = pd.DataFrame()
for año in lista_años:
	url = "https://moviesdatabase.p.rapidapi.com/titles"

	querystring = {"genre":"Action","startYear":str(año) ,"sort":"year.incr"}
	headers = {
		"x-rapidapi-key": API_KEY,
		"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	data = response.json()
	df_temp = pd.DataFrame(data['results'])
	df_Action = pd.concat([df_temp, df_Action], ignore_index=True)
	print(response.json())
# Out:
# {'page': 1, 'next': '/titles?genre=Action&startYear=1990&sort=year.incr&page=2', 'entries': 10, 'results': [{'_id': '61e580fe95801a78bc414fd3', 'id': 'tt0075259', 'primaryImage': {'id': 'rm3423950592', 'width': 600, 'height': 900, 'url': 'https://m.media-amazon.com/images/M/MV5BMTQ3NTc4YjgtNTY4Ni00Y2Y5LWE1NDctYmZlODcwY2QwMmNjXkEyXkFqcGdeQXVyMTg2NjYzOA@@._V1_.jpg', 'caption': {'plainText': 'Spy Story (1990)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Spy Story', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Spy Story', '__typename': 'TitleText'}, 'releaseYear': {'year': 1990, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 23, 'month': 3, 'year': 1990, '__typename': 'ReleaseDate'}}, {'_id': '61e58136971a4a15d64159e7', 'id': 'tt0090869', 'primaryImage': None, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSer
# ...

# %%
df_Action["genero"] = "Action"

# %%
df_Fantasy = pd.DataFrame()
for año in lista_años:
	url = "https://moviesdatabase.p.rapidapi.com/titles"

	querystring = {"genre":"Fantasy","startYear":str(año) ,"sort":"year.incr"}
	headers = {
		"x-rapidapi-key": API_KEY,
		"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	data = response.json()
	df_temp = pd.DataFrame(data['results'])
	df_Fantasy = pd.concat([df_temp, df_Fantasy], ignore_index=True)
	print(response.json())
# Out:
# {'page': 1, 'next': '/titles?genre=Fantasy&startYear=1990&sort=year.incr&page=2', 'entries': 10, 'results': [{'_id': '61e580c8d8f3c0931e414665', 'id': 'tt0059900', 'primaryImage': {'id': 'rm2847710208', 'width': 290, 'height': 475, 'url': 'https://m.media-amazon.com/images/M/MV5BMTYzOTEzNTQ3Ml5BMl5BanBnXkFtZTcwNjM4MzAyMQ@@._V1_.jpg', 'caption': {'plainText': 'Wenn du groß bist, lieber Adam (1990)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Wenn du groß bist, lieber Adam', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Wenn du groß bist, lieber Adam', '__typename': 'TitleText'}, 'releaseYear': {'year': 1990, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 18, 'month': 10, 'year': 1990, '__typename': 'ReleaseDate'}}, {'_id': '61e58117cffb8f2faa41543b', 'id': 'tt0081721', 'primaryImage': {'id': 'rm1878772224', 'w
# ...

# %%
df_Fantasy["genero"] = "Fantasy"

# %%
df_Horror = pd.DataFrame()
for año in lista_años:
	url = "https://moviesdatabase.p.rapidapi.com/titles"

	querystring = {"genre":"Horror","startYear":str(año) ,"sort":"year.incr"}
	headers = {
		"x-rapidapi-key": API_KEY,
		"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	data = response.json()
	df_temp = pd.DataFrame(data['results'])
	df_Horror = pd.concat([df_temp, df_Horror], ignore_index=True)
	print(response.json())
# Out:
# {'page': 1, 'next': '/titles?genre=Horror&startYear=1990&sort=year.incr&page=2', 'entries': 10, 'results': [{'_id': '61e58140cffb8f2faa415bad', 'id': 'tt0093211', 'primaryImage': {'id': 'rm1773149440', 'width': 583, 'height': 698, 'url': 'https://m.media-amazon.com/images/M/MV5BZDI2YmQwYWEtN2FiMi00MDg3LWI4YmYtNDgwNTgzMmJjODdlXkEyXkFqcGdeQXVyMTkwMjU3Nw@@._V1_.jpg', 'caption': {'plainText': 'Horrorshow (1990)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Short', 'id': 'short', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Horrorshow', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Horrorshow', '__typename': 'TitleText'}, 'releaseYear': {'year': 1990, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': None, 'month': None, 'year': 1990, '__typename': 'ReleaseDate'}}, {'_id': '61e5814395801a78bc415c15', 'id': 'tt0094997', 'primaryImage': {'id': 'rm4114736128', 'width': 600, 'height': 888
# ...

# %%
df_Horror["genero"] = "Horror"

# %%
df_Mystery = pd.DataFrame()
for año in lista_años:
	url = "https://moviesdatabase.p.rapidapi.com/titles"

	querystring = {"genre":"Mystery","startYear":str(año) ,"sort":"year.incr"}
	headers = {
		"x-rapidapi-key": API_KEY,
		"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	data = response.json()
	df_temp = pd.DataFrame(data['results'])
	df_Mystery = pd.concat([df_temp, df_Mystery], ignore_index=True)
	print(response.json())
# Out:
# {'page': 1, 'next': '/titles?genre=Mystery&startYear=1990&sort=year.incr&page=2', 'entries': 10, 'results': [{'_id': '61e580fe95801a78bc414fd3', 'id': 'tt0075259', 'primaryImage': {'id': 'rm3423950592', 'width': 600, 'height': 900, 'url': 'https://m.media-amazon.com/images/M/MV5BMTQ3NTc4YjgtNTY4Ni00Y2Y5LWE1NDctYmZlODcwY2QwMmNjXkEyXkFqcGdeQXVyMTg2NjYzOA@@._V1_.jpg', 'caption': {'plainText': 'Spy Story (1990)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Spy Story', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Spy Story', '__typename': 'TitleText'}, 'releaseYear': {'year': 1990, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 23, 'month': 3, 'year': 1990, '__typename': 'ReleaseDate'}}, {'_id': '61e5812d971a4a15d6415831', 'id': 'tt0088283', 'primaryImage': None, 'titleType': {'text': 'TV Episode', 'id': 'tvEpisod
# ...

# %%
df_Mystery["genero"] = "Mystery"

# %%
df_Romance = pd.DataFrame()
for año in lista_años:
	url = "https://moviesdatabase.p.rapidapi.com/titles"

	querystring = {"genre":"Romance","startYear":str(año) ,"sort":"year.incr"}
	headers = {
		"x-rapidapi-key": API_KEY,
		"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	data = response.json()
	df_temp = pd.DataFrame(data['results'])
	df_Romance = pd.concat([df_temp, df_Romance], ignore_index=True)
	print(response.json())
# Out:
# {'page': 1, 'next': '/titles?genre=Romance&startYear=1990&sort=year.incr&page=2', 'entries': 10, 'results': [{'_id': '61e580c3971a4a15d641458b', 'id': 'tt0059325', 'primaryImage': {'id': 'rm3431504896', 'width': 292, 'height': 475, 'url': 'https://m.media-amazon.com/images/M/MV5BMTc0Mzk0Mjg2MF5BMl5BanBnXkFtZTcwMzU4NzAyMQ@@._V1_.jpg', 'caption': {'plainText': 'Jahrgang 45 (1990)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Jahrgang 45', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Jahrgang 45', '__typename': 'TitleText'}, 'releaseYear': {'year': 1990, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 11, 'month': 10, 'year': 1990, '__typename': 'ReleaseDate'}}, {'_id': '61e581478a5a6a599f415cb5', 'id': 'tt0095673', 'primaryImage': None, 'titleType': {'text': 'TV Episode', 'id': 'tvEpisode', 'isSeries': False, 'i
# ...

# %%
df_Romance["genero"] = "Romance"

# %%
df_Thriller = pd.DataFrame()
for año in lista_años:
	url = "https://moviesdatabase.p.rapidapi.com/titles"

	querystring = {"genre":"Thriller","startYear":str(año) ,"sort":"year.incr"}
	headers = {
		"x-rapidapi-key": API_KEY,
		"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	data = response.json()
	df_temp = pd.DataFrame(data['results'])
	df_Thriller = pd.concat([df_temp, df_Thriller], ignore_index=True)
	print(response.json())
# Out:
# {'page': 1, 'next': '/titles?genre=Thriller&startYear=1990&sort=year.incr&page=2', 'entries': 10, 'results': [{'_id': '61e580fe95801a78bc414fd3', 'id': 'tt0075259', 'primaryImage': {'id': 'rm3423950592', 'width': 600, 'height': 900, 'url': 'https://m.media-amazon.com/images/M/MV5BMTQ3NTc4YjgtNTY4Ni00Y2Y5LWE1NDctYmZlODcwY2QwMmNjXkEyXkFqcGdeQXVyMTg2NjYzOA@@._V1_.jpg', 'caption': {'plainText': 'Spy Story (1990)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Spy Story', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Spy Story', '__typename': 'TitleText'}, 'releaseYear': {'year': 1990, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 23, 'month': 3, 'year': 1990, '__typename': 'ReleaseDate'}}, {'_id': '61e5812d971a4a15d6415831', 'id': 'tt0088283', 'primaryImage': None, 'titleType': {'text': 'TV Episode', 'id': 'tvEpiso
# ...

# %%
df_Thriller["genero"] = "Thriller"

# %%
dataframes = [df_drama, df_comedy, df_Action, df_Fantasy, df_Horror, df_Mystery, df_Romance, df_Thriller]
df = pd.concat(dataframes, ignore_index=True)

# %%
df.drop(["_id", "primaryImage"], axis=1, inplace=True)

# %%
df.head(1)
# Out:
#           id                                          titleType  \
# 0  tt0062336  {'text': 'Movie', 'id': 'movie', 'isSeries': F...
#
#                                            titleText  \
# 0  {'text': 'El Tango del Viudo y Su Espejo Defor...
#
#                                    originalTitleText  \
# 0  {'text': 'El Tango del Viudo y Su Espejo Defor...
#
#                                          releaseYear  \
# 0  {'year': 2020, 'endYear': None, '__typename': ...
#
#                                          releaseDate genero
# 0  {'day': 20, 'month': 2, 'year': 2020, '__typen...  drama

# %%
df["titleType"][0]
# Out:
# {'text': 'Movie',
#  'id': 'movie',
#  'isSeries': False,
#  'isEpisode': False,
#  '__typename': 'TitleType'}

# %%
df["titleText"][0]
# Out:
# {'text': 'El Tango del Viudo y Su Espejo Deformante',
#  '__typename': 'TitleText'}

# %%
df["originalTitleText"][0]
# Out:
# {'text': 'El Tango del Viudo y Su Espejo Deformante',
#  '__typename': 'TitleText'}

# %%
df["releaseYear"][0]
# Out:
# {'year': 2020, 'endYear': None, '__typename': 'YearRange'}

# %%
df["releaseDate"][5]
# Out:
# {'day': 18, 'month': 9, 'year': 2020, '__typename': 'ReleaseDate'}

# %% [markdown]
# > Me cargo esta columna `releaseDate`, ya que todos los diccionarios que tiene dentro, en sus claves contiene "none"

# %%
# df.drop("releaseDate", inplace=True, axis=1)

# %%
df['mes'] = df['releaseDate'].apply(lambda x: x.get('month') if isinstance(x, dict) else None)

# %%
df["mes"]= df["mes"].fillna("Unknown")

# %%
df['año'] = df['releaseYear'].apply(lambda x: x.get('year'))

# %%
df['titulo'] = df['originalTitleText'].apply(lambda x: x.get('text'))

# %%
df['tipo'] = df['titleType'].apply(lambda x: x.get('text'))

# %%
df.drop(["releaseYear","releaseDate", "titleText", "titleType", "originalTitleText"], axis=1, inplace=True)

# %%
df
# Out:
#             id    genero  mes   año  \
# 0    tt0062336     drama    2  2020
# 1    tt0383477     drama    7  2020
# 2    tt0425118     drama    5  2020
# 3    tt0446792     drama    8  2020
# 4    tt0849437     drama    8  2020
# ..         ...       ...  ...   ...
# 554  tt0088657  Thriller   11  1990
# 555  tt0094004  Thriller    4  1990
# 557  tt0094666  Thriller    5  1990
# 558  tt0094857  Thriller    3  1990
# 559  tt0095840  Thriller    4  1990
#
#                                                 titulo        tipo
# 0            El Tango del Viudo y Su Espejo Deformante       Movie
# 1                                       Love & Orgasms       Movie
# 2                             I Know This Much Is True   TV Series
# 3                                    Surviving in L.A.       Movie
# 4                                      Duel of Legends       Movie
# ..                                                 ...         ...
# ...

# %%
df['fecha'] = df.mes.astype(str).str.cat(df.año.astype(str), sep='-')
# Out:
# C:\Users\almaz\AppData\Local\Temp\ipykernel_19148\1911070137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha'] = df.mes.astype(str).str.cat(df.año.astype(str), sep='-')

# %%
df.drop(["mes", "año"], inplace=True, axis=1)
# Out:
# C:\Users\almaz\AppData\Local\Temp\ipykernel_19148\1268720597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["mes", "año"], inplace=True, axis=1)

# %%
df.to_csv("datosAPI.csv")

# %%
df
# Out:
#             id    genero                                             titulo  \
# 0    tt0062336     drama          El Tango del Viudo y Su Espejo Deformante
# 1    tt0383477     drama                                     Love & Orgasms
# 2    tt0425118     drama                           I Know This Much Is True
# 3    tt0446792     drama                                  Surviving in L.A.
# 4    tt0849437     drama                                    Duel of Legends
# ..         ...       ...                                                ...
# 554  tt0088657  Thriller  Shita wo kamu otoko (The Man Who Bites His Ton...
# 555  tt0094004  Thriller                                 Soldier of Fortune
# 557  tt0094666  Thriller                                    Any Man's Death
# 558  tt0094857  Thriller                                 Chi se da feng bao
# 559  tt0095840  Thriller                                            Payback
#
#            tipo    fecha
# 0         Movie   2-2020
# ...

# %%
listas_id = df["id"].tolist()

# %%
listas_id[0]
# Out:
# 'tt0062336'

# %%
import sys
sys.path.append("../")
from src import soporte_scrap as ss

# %%
url_imdb = "https://www.imdb.com/es/"

# %%
data_imbdb = ss.traer_datos(url_imdb)

# %%
print(data_imbdb)
# Out:
# None

# %%
df
# Out:
#             id    genero                                             titulo  \
# 0    tt0062336     drama          El Tango del Viudo y Su Espejo Deformante
# 1    tt0383477     drama                                     Love & Orgasms
# 2    tt0425118     drama                           I Know This Much Is True
# 3    tt0446792     drama                                  Surviving in L.A.
# 4    tt0849437     drama                                    Duel of Legends
# ..         ...       ...                                                ...
# 554  tt0088657  Thriller  Shita wo kamu otoko (The Man Who Bites His Ton...
# 555  tt0094004  Thriller                                 Soldier of Fortune
# 557  tt0094666  Thriller                                    Any Man's Death
# 558  tt0094857  Thriller                                 Chi se da feng bao
# 559  tt0095840  Thriller                                            Payback
#
#            tipo    fecha
# 0         Movie   2-2020
# ...

# %%
df.dtypes
# Out:
# id        object
# genero    object
# titulo    object
# tipo      object
# fecha     object
# dtype: object
